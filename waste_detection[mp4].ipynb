# %%
import cv2
import math
import cvzone
from ultralytics import YOLO
import pandas as pd
import yaml
from collections import defaultdict
from sklearn.metrics import accuracy_score

# %%
waste_categories = {
    "Recyclable": {
        "Dry Waste": ["aluminum", "cardboard", "paper", "glass bottle", "plastic bag", "plastic bottle", "plastic container", "plastic straw"],
        "E-Waste": ["Keyboard", "Mobile Phone", "Monitor"]
    },
    "Non-Recyclable": {
        "Wet Waste": ["egg shell", "facemask", "food wrapper", "fruit peels", "treeleaves", "vegetable peels"]
    }
}

# %%
# Load YOLO model
model = YOLO("D:/Waste_Detection_New/best_0.pt")

# %%
# Load video
video_path = "D:/Waste_Detection_New/Waste_detect.mp4"
cap = cv2.VideoCapture(video_path)

# %%
# Initialize waste summary dictionary
waste_summary = {"Recyclable": {"Dry Waste": defaultdict(int), "E-Waste": defaultdict(int)}, "Non-Recyclable": {"Wet Waste": defaultdict(int)}}
object_tracker = {}  # Track detected objects using their positions
next_object_id = 0  # ID counter for unique objects

# %%
# Accuracy calculation variables
correct_predictions = 0
total_predictions = 0
frame_idx = 0

# %%
def get_center(box):
    x1, y1, x2, y2 = map(int, box.xyxy[0])
    return (x1 + x2) // 2, (y1 + y2) // 2

# %%
while cap.isOpened():
    ret, frame = cap.read()
    if not ret:
        break

    # Run YOLOv8 detection
    results = model(frame)
    predicted_labels = []
    new_objects = {}
    
    for r in results:
        for box in r.boxes:
            class_id = int(box.cls[0])
            label = model.names[class_id]
            conf = box.conf[0].item()
            center = get_center(box)
            predicted_labels.append(label)
            
            # Check if object is new or already tracked
            found = False
            for obj_id, prev_center in object_tracker.items():
                if isinstance(prev_center, tuple) and len(prev_center) == 2:
                    if abs(center[0] - prev_center[0]) < 50 and abs(center[1] - prev_center[1]) < 50:
                        object_tracker[obj_id] = center  # Ensure (x, y) tuple is stored
                        found = True
                        break
            
            if not found:
                new_objects[next_object_id] = (center[0], center[1])  # Store as tuple
                for category, subcategories in waste_categories.items():
                    for subcategory, items in subcategories.items():
                        if label in items:
                            waste_summary[category][subcategory][label] += 1
                next_object_id += 1
            
            # Draw bounding box and label on frame
            x1, y1, x2, y2 = map(int, box.xyxy[0])
            cv2.rectangle(frame, (x1, y1), (x2, y2), (0, 255, 0), 2)
            cv2.putText(frame, f"{label} {conf:.2f}", (x1, y1 - 10),
                        cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 255, 0), 2)
    
    # Set first frame as ground truth
    if frame_idx == 0:
        object_tracker = {label: (0, 0) for label in predicted_labels}  # Ensure tuples
    
    # Compare current frame predictions with tracked objects
    for label in predicted_labels:
        if label in object_tracker:
            correct_predictions += 1
        total_predictions += 1
    
    frame_idx += 1
    object_tracker.update(new_objects)
    
    # Show detection frame
    cv2.imshow("Waste Detection", frame)
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# 0: 384x640 1 cardboard, 6 plastic bags, 513.2ms
# Speed: 10.0ms preprocess, 513.2ms inference, 6.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cardboards, 7 plastic bags, 425.7ms
# Speed: 6.3ms preprocess, 425.7ms inference, 8.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cardboards, 8 plastic bags, 427.2ms
# Speed: 4.0ms preprocess, 427.2ms inference, 7.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 cardboard, 8 plastic bags, 399.9ms
# Speed: 3.0ms preprocess, 399.9ms inference, 8.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 cardboard, 7 plastic bags, 408.7ms
# Speed: 3.0ms preprocess, 408.7ms inference, 9.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 plastic bags, 437.8ms
# Speed: 3.0ms preprocess, 437.8ms inference, 7.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 cardboard, 9 plastic bags, 413.2ms
# Speed: 3.0ms preprocess, 413.2ms inference, 8.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 cardboard, 8 plastic bags, 473.6ms
# Speed: 3.0ms preprocess, 473.6ms inference, 10.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 cardboard, 7 plastic bags, 435.6ms
# Speed: 5.0ms preprocess, 435.6ms inference, 7.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 plastic bags, 501.8ms
# Speed: 8.0ms preprocess, 501.8ms inference, 8.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8
ms inference, 6.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cardboards, 1 facemask, 8 plastic bags, 1 vegetable peels, 412.9ms
# Speed: 3.0ms preprocess, 412.9ms inference, 9.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cardboards, 1 facemask, 6 plastic bags, 1 vegetable peels, 399.3ms
# Speed: 4.0ms preprocess, 399.3ms inference, 9.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cardboards, 7 plastic bags, 1 vegetable peels, 411.2ms
# Speed: 2.0ms preprocess, 411.2ms inference, 7.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cardboards, 1 facemask, 5 plastic bags, 1 vegetable peels, 597.4ms
# Speed: 3.0ms preprocess, 597.4ms inference, 8.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cardboards, 1 facemask, 7 plastic bags, 717.9ms
# Speed: 4.0ms preprocess, 717.9ms inference, 12.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cardboards, 1 facemask, 8 plastic bags, 740.6ms
# Speed: 6.0ms preprocess, 740.6ms inference, 14.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cardboards, 1 facemask, 5 plastic bags, 1301.9ms
# Speed: 4.0ms preprocess, 1301.9ms inference, 13.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cardboards, 1 facemask, 6 plastic bags, 1339.1ms
# Speed: 4.3ms preprocess, 1339.1ms inference, 19.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cardboards, 1 facemask, 7 plastic bags, 1571.3ms
# Speed: 5.0ms preprocess, 1571.3ms inference, 19.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cardboards, 9 plastic bags, 1446.8ms
# Speed: 6.5ms preprocess, 1446.8ms inference, 17.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cardboards, 1 facemask, 8 plastic bags, 1324.0ms
# Speed: 5.4ms preprocess, 1324.0ms inference, 16.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cardboards, 9 plastic bags, 1243.3ms
# Speed: 6.0ms preprocess, 1243.3ms inference, 15.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cardboards, 9 plastic bags, 1145.7ms
# Speed: 5.0ms preprocess, 1145.7ms inference, 19.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cardboards, 9 plastic bags, 1107.8ms
# Speed: 5.0ms preprocess, 1107.8ms inference, 10.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cardboards, 1 facemask, 9 plastic bags, 928.9ms
# Speed: 4.0ms preprocess, 928.9ms inference, 17.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cardboards, 1 facemask, 10 plastic bags, 537.2ms
# Speed: 5.6ms preprocess, 537.2ms inference, 11.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cardboards, 1 facemask, 10 plastic bags, 752.5ms
# Speed: 3.0ms preprocess, 752.5ms inference, 18.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cardboards, 1 facemask, 8 plastic bags, 1185.3ms
# Speed: 5.1ms preprocess, 1185.3ms inference, 17.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cardboards, 1 facemask, 10 plastic bags, 1178.5ms
# Speed: 5.0ms preprocess, 1178.5ms inference, 19.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cardboards, 1 facemask, 9 plastic bags, 829.4ms
# Speed: 5.0ms preprocess, 829.4ms inference, 12.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cardboards, 9 plastic bags, 518.6ms
# Speed: 5.4ms preprocess, 518.6ms inference, 12.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cardboards, 7 plastic bags, 527.6ms
# Speed: 4.0ms preprocess, 527.6ms inference, 9.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cardboards, 8 plastic bags, 555.4ms
# Speed: 6.0ms preprocess, 555.4ms inference, 12.0ms postprocess per image at shape (1, 3, 384, 640)

# %%
# Calculate accuracy
video_accuracy = (correct_predictions / total_predictions) * 100 if total_predictions > 0 else 0

# %%
# Save accuracy to CSV
accuracy_data = pd.DataFrame({'Metric': ['Video Accuracy'], 'Value': [video_accuracy]})
accuracy_data.to_csv("video_model_accuracy.csv", index=False)

# %%
# Generate structured summary table
summary_list = []
for category, subcategories in waste_summary.items():
    for subcategory, items in subcategories.items():
        for item, count in items.items():
            summary_list.append([category, subcategory, item, count])

# %%
waste_df = pd.DataFrame(summary_list, columns=["Category", "Subcategory", "Waste Type", "Count"])

# Append accuracy to summary
accuracy_row = pd.DataFrame([["Model Performance", "", "Accuracy", video_accuracy]], columns=["Category", "Subcategory", "Waste Type", "Count"])
waste_df = pd.concat([waste_df, accuracy_row], ignore_index=True)
waste_df.to_csv("waste_summary.csv", index=False)

# Print final structured summary
print("Final Waste Classification Summary:")
print(waste_df)
print("Video Model Accuracy:", video_accuracy, "%")
# Out:
# Final Waste Classification Summary:
#             Category Subcategory       Waste Type      Count
# 0         Recyclable   Dry Waste      plastic bag  28.000000
# 1         Recyclable   Dry Waste        cardboard   3.000000
# 2     Non-Recyclable   Wet Waste  vegetable peels   2.000000
# 3  Model Performance                     Accuracy  92.032967
# Video Model Accuracy: 92.03296703296702 %
